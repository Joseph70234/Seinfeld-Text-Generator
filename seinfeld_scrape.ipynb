# %%
# import libraries
import requests
from bs4 import BeautifulSoup
import time

# %%
# set up urls
base_url = "https://www.seinfeldscripts.com/"
main_url = f"{base_url}seinfeld-scripts.html"

# %%
# set header to look more legit
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36"
}

# %%
# request the main page

response = requests.get(main_url, headers=headers) # sends get request to obtain main page content

if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")
        # response.text gets HTML content from main page as string
        # parse HTML from response.text with html.parser
else:
    print("Failed to retrieve the page. Status code:", response.status_code)

# %%
# find all links to epsode pages
episode_links = soup.select("td a")
cleaned_links = []
for link in episode_links:
    new_link = link['href'].strip()
    cleaned_links.append(new_link)

# %%
i = 0
for link in cleaned_links:
    print(i)
    print(link)
    i += 1
# Out:
# 0
# TheSeinfeldChronicles.htm
# 1
# TheStakeout.htm
# 2
# TheRobbery.htm
# 3
# MaleUnbonding.htm
# 4
# TheStockTip.htm
# 5
# TheExGirlfriend.htm
# 6
# ThePonyRemark.htm
# 7
# TheJacket.htm
# 8
# ThePhoneMessage.htm
# 9
# TheApartment.htm
# 10
# TheStatue.htm
# 11
# TheRevenge.htm
# 12
# TheHeartAttack.htm
# 13
# TheDeal.htm
# 14
# TheBabyShower.htm
# 15
# TheChineseRestaurant.htm
# 16
# TheBusboy.htm
# 17
# TheNote.html
# 18
# TheTruth.htm
# 19
# ThePen.html
# 20
# TheDog.htm
# 21
# TheLibrary.htm
# 22
# TheParkingGarage.htm
# 23
# TheCafe.html
# 24
# TheTape.htm
# 25
# TheNoseJob.html
# 26
# TheStranded.html
# 27
# TheAlternateSide.htm
# 28
# TheRedDot.htm
# 29
# TheSubway.htm
# 30
# ThePezDispenser.htm
# 31
# TheSuicide.html
# 32
# TheFixUp.html
# 33
# TheBoyfriend1.htm
# 34
# TheBoyfriend2.htm
# 35
# TheLimo.html
# 36
# TheGoodSamaritan.html
# 37
# TheLetter.htm
# 38
# TheParkingSpace.html
# 39
# TheKeys.html
# 40
# TheTrip1.htm
# 41
# TheTrip2.html
# 42
# ThePitch.htm
# 43
# TheTicket.html
# 44
# TheWallet.html
# 45
# TheWatch.html
# 46
# TheBubbleBoy.htm
# 47
# TheCheeverLetters.htm
# 48
# TheOpera.html
# 49
# TheVirgin.htm
# 50
# TheContest.htm
# 51
# TheAirport.htm
# 52
# ThePick.htm
# 53
# TheMovie.htm
# 54
# TheVisa.html
# 55
# TheShoes.html
# 56
# TheOuting.htm
# 57
# TheOldMan.htm
# 58
# TheImplant.html
# 59
# TheJuniorMints.htm
# 60
# TheSmellyCar.htm
# 61
# TheHandicapSpot.html
# 62
# ThePilot.html
# 63
# ThePilot2.html
# 64
# TheMango.html
# 65
# ThePuffyShirt.htm
# 66
# TheGlasses.html
# 67
# TheSniffingAccountant.htm
# 68
# TheBris.htm
# 69
# TheLipReader.htm
# 70
# TheNonFatYogurt.html
# 71
# TheBarber.htm
# 72
# TheMasseuse.html
# 73
# TheCigarStoreIndian.htm
# 74
# TheConversion.htm
# 75
# TheStall.htm
# 76
# TheDinnerParty.html
# 77
# TheMarineBiologist.htm
# 78
# ThePie.html
# 79
# TheStand-In.html
# 80
# TheWife.html
# 81
# TheRaincoats.html
# 82
# TheRaincoats2.html
# 83
# TheFire.html
# 84
# TheHamptons.htm
# 85
# TheOpposite.htm
# 86
# TheChaperone.html
# 87
# TheBigSalad.html
# 88
# ThePledgeDrive.html
# 89
# TheChineseWoman.htm
# 90
# TheCouch.html
# 91
# TheGymnast.html
# 92
# TheSoup.html
# 93
# TheMomAndPopStore.html
# 94
# TheSecretary.html
# 95
# TheRace.html
# 96
# TheSwitch.htm
# 97
# TheLabelMaker.html
# 98
# TheScofflaw.htm
# 99
# Highlights-of-100-1.html
# 100
# Highlights-of-100-2.html
# 101
# TheBeard.htm
# 102
# TheKissHello.html
# 103
# TheDoorman.html
# 104
# TheJimmy.htm
# 105
# TheDoodle.htm
# 106
# TheFusilliJerry.htm
# 107
# TheDiplomatClub.htm
# 108
# TheFacePainter.html
# 109
# TheUnderstudy.html
# 110
# TheEngagement.html
# 111
# ThePostponement.html
# 112
# TheMaestro.htm
# 113
# TheWink.html
# 114
# TheHotTub.htm
# 115
# TheSoupNazi.htm
# 116
# TheSecretCode2.htm
# 117
# ThePoolGuy.html
# 118
# TheSponge.html
# 119
# TheGum.html
# 120
# TheRye.htm
# 121
# TheCaddy.html
# 122
# TheSeven.html
# 123
# TheCadillac1.html
# 124
# TheCadillac2.html
# 125
# TheShowerhead.htm
# 126
# TheDoll.htm
# 127
# TheFriarsClub.html
# 128
# TheWigMaster.htm
# 129
# TheCalzone.htm
# 130
# TheBottleDeposit1.html
# 131
# TheBottleDeposit2.html
# 132
# TheWaitOut.htm
# 133
# TheInvitations.htm
# 134
# TheFoundation.html
# 135
# TheSoulMate.html
# 136
# TheBizarroJerry.htm
# 137
# TheLittleKicks.htm
# 138
# ThePackage.htm
# 139
# TheFatigues.html
# 140
# TheChecks.html
# 141
# TheChickenRoaster.htm
# 142
# TheAbstinence.htm
# 143
# TheAndreaDoria.htm
# 144
# TheLittleJerry.html
# 145
# TheMoney.html
# 146
# TheComeback.html
# 147
# TheVanBurenBoys.htm
# 148
# TheSuzie.htm
# 149
# ThePothole.htm
# 150
# TheEnglishPatient.html
# 151
# TheNap.html
# 152
# TheYadaYada.htm
# 153
# TheMillennium.html
# 154
# TheMuffinTops.htm
# 155
# TheSummerofGeorge.htm
# 156
# TheButterShave.htm
# 157
# TheVoice.htm
# 158
# TheSerenityNow.htm
# 159
# TheBlood.html
# 160
# TheJunkMail.htm
# 161
# TheMervGriffinShow.htm
# 162
# TheSlicer.html
# 163
# TheBetrayal.htm
# 164
# TheApology.htm
# 165
# TheStrike.htm
# 166
# TheDealership.htm
# 167
# TheReversePeephole.htm
# 168
# TheCartoon.htm
# 169
# TheStrongbox.htm
# 170
# TheWizard.htm
# 171
# TheBurning.html
# 172
# TheBookstore.htm
# 173
# TheFrogger.htm
# 174
# TheMaid.htm
# 175
# ThePuertoRicanDay.htm
# 176
# The-Clip-Show-1.html
# 177
# The-Clip-Show-2.html
# 178
# TheFinale.htm
# 179
# TheFinale.htm
# 180
# http://www.shareasale.com/r.cfm?u=439896&b=119192&m=16934&afftrack=seinfeldScriptsBottom&urllink=search%2E80stees%2Ecom%2F%3Fcategory%3D80s%2BTV%26i%3D1%26theme%3DSeinfeld%26u1%3Dcategory%26u2%3Dtheme

# %%
cleaned_links.remove('Highlights-of-100-1.html')
cleaned_links.remove('Highlights-of-100-2.html')
cleaned_links.remove('The-Clip-Show-1.html')
cleaned_links.remove('The-Clip-Show-2.html')
cleaned_links.remove(cleaned_links[-1])
cleaned_links.remove(cleaned_links[-1])

# %%
import re

# create bins
all_titles = []
all_scripts = [] # object to hold each episode's script

# set start and end keywords
start_keywords = ["[scene", "Opening Monologue", "[setting", "levitan:", "every time somebody", "stand up", "act one", "at the comedy club", "monk's caf", "[jerry", "do you think that the people", "(jerry is driving alone", "act 1", "JERRY'S APARTMENT", "[New York State", "[Montage", "Jerry and George talking near a bar.", "Jerry I've always been a big", "[Night", "(the bathroom)", "[At club", "Monologue", "Jerry's stand-up", "[location:", "Mr. Tuttle", "[George's", "[Elaine", "GEORGE:", "ELAINE: [thinking]", "George in a meeting", "Opening scene", "Jerry and", "Elaine at", "high LS following", "[Monks", "[George", "Exterior of", "(Scene:", "The Costanzas are driving", "Jerry, on the", "(The final", "Jerry, [tapping", "Waitress giving", "Some street , Jerry", "George, drinking", "First scene.", "INT. "]
end_keywords = ["<Spell", "end of show", "episodes overview", "[end]"]

# set ad phrase to avoid
ad = "Looking for a great gift idea for the holidays? Check out our complete Seinfeld Gift Guide right now! Including T-Shirts, DVDs, and more!"

# avoid errors from certain unfinished transcripts
okay_links = ['https://www.seinfeldscripts.com/TheWaitOut.htm', 'https://www.seinfeldscripts.com/TheSuzie.htm']

# loop through episodes for scripts
for link in cleaned_links:

    # link setup
    episode_url = base_url + link # construct full link, strip space from href
    print(f"retrieving from: {episode_url}")

    # create soup
    episode_response = requests.get(episode_url, headers=headers)
    episode_soup = BeautifulSoup(episode_response.text, "html.parser")

    # extract title
    episode_title = episode_soup.find("h1").get_text(strip=True)
    print(f"episode title: {episode_title}")

    # extract script
    script_content = ""                                                             # create script bin
    for p_tag in episode_soup.find_all("p"):                                        # find all p tags in html                                    
        if len(p_tag.text.strip()) > 0:                                             # Only include non-empty paragraphs
            dialogue_line = p_tag.get_text(separator="").strip().replace("\n", "")  # get text; clean leading and trailing spaces; remove all \n
            dialogue_line = re.sub(r'\s+', ' ', dialogue_line)                      # change multiple spaces to one space
            dialogue_line = re.sub(r'===+', '', dialogue_line)
            dialogue_line = re.sub(r'---+', '', dialogue_line)
            dialogue_line = re.sub(r'~~~+', '', dialogue_line)
            dialogue_line = dialogue_line.replace(ad, '')                           # get rid of ad line
            script_content += dialogue_line + "\n"                                  # add line followed by newline for readability

    script_length = len(script_content)

    # find starting point of actual dialogue (get rid of heading)
    start_incidence_list = []                                                       # create incidence bin (incidence means first keyword to signify start of real dialogue
    for keyword in start_keywords:                                          
        start_incidences = str.lower(script_content).find(str.lower(keyword))       # find the location of the first incidence of each keyword
        start_incidence_list.append(start_incidences)                               # add each location of keyword to a list

    # find ending point of actual dialogue (get rid of footer)
    end_incidence_list = []
    for keyword in end_keywords:
        end_incidences = str.lower(script_content).find(str.lower(keyword))
        end_incidence_list.append(end_incidences)

    # check incidence list to find start point
    try:
        min_incidence = min([num for num in start_incidence_list if num != -1])
        min_incidence_keyword = script_content[min_incidence:min_incidence + 10]
    # raise error if none of the keywords are found
    except ValueError:
        print("Error: Could not find any starting keywords.")
        raise TypeError
    
    # check incidence list to find end point
    try:
        max_incidence = min([num for num in end_incidence_list if num != -1])
        max_incidence_keyword = script_content[max_incidence:max_incidence + 10]
    # raise error if none of the keywords are found
    except ValueError:
        print("Error: Could not find any ending keywords.")
        raise TypeError

    # if both start and endpoint, start scraping (also print out some info for diagnostics)
    if (min_incidence != -1) and (max_incidence != -1):
        print(f"reading from character/word: {min_incidence_keyword} at position {min_incidence}")
        print(f"reading until character/word: {max_incidence_keyword} at position {max_incidence}")

        total_incidence = max_incidence - min_incidence
        print(f"total copied characters: {total_incidence}")

        script_content = script_content[min_incidence:max_incidence-1]

        if min_incidence > 2000 and episode_url not in okay_links:
            print("Error: Late starting point.")
            raise TypeError
        if total_incidence < 15000 and episode_url not in okay_links:
            print("Error: Low number of characters for episode.")
            raise TypeError
        
        
        #character_percent = (max_incidence - min_incidence) / script_length
        #print(f"percentage of characters copied: {round(character_percent*100, 2)}%")
        #if character_percent < 0.90:
        #    print("Error: Low percentage of total characters copied.")
        #    raise TypeError

    # avoid overloading the server (be polite)
    time.sleep(1) # wait 1 second between requests

    # add title and script to bins
    all_titles.append(episode_title)
    all_scripts.append(script_content)

    print()
# Out:
# retrieving from: https://www.seinfeldscripts.com/TheSeinfeldChronicles.htm
# episode title: The Seinfeld Chronicles
# reading from character/word: [Scene: Co at position 1
# reading until character/word: <Spell che at position 23321
# total copied characters: 23320
#
# retrieving from: https://www.seinfeldscripts.com/TheStakeout.htm
# episode title: The Stakeout
# reading from character/word: Opening mo at position 1256
# reading until character/word: [End]
#
# <Sp at position 23362
# total copied characters: 22106
#
# retrieving from: https://www.seinfeldscripts.com/TheRobbery.htm
# episode title: The Robbery
# reading from character/word: [Scene: Co at position 1
# reading until character/word: <Spell che at position 22336
# total copied characters: 22335
#
# retrieving from: https://www.seinfeldscripts.com/MaleUnbonding.htm
# episode title: Male Unbonding
# reading from character/word: [Setting:  at position 222
# reading until character/word: END OF SHO at position 20559
# total copied characters: 20337
#
# retrieving from: https://www.seinfeldscripts.com/TheStockTip.htm
# episode title: The Stock Tip
# reading from character/word: [Setting:  at position 226
# reading until character/word: END OF SHO at position 20212
# total copied characters: 19986
#
# retrieving from: https://www.seinfeldscripts.com/TheExGirlfriend.htm
# episode title: The Ex-Girlfriend
# reading from character/word: [Setting:  at position 230
# reading until character/word: END OF SHO at position 21210
# total copied characters: 20980
#
# episode title: The Opposite
# reading from character/word: Opening mo at position 3
# reading until character/word: Episodes O at position 21955
# total copied characters: 21952
#
# retrieving from: https://www.seinfeldscripts.com/TheChaperone.html
# episode title: The Chaperone
# reading from character/word: Jerry's st at position 338
# reading until character/word: Episodes O at position 23294
# total copied characters: 22956
#
# retrieving from: https://www.seinfeldscripts.com/TheBigSalad.html
# episode title: The Big Salad
# reading from character/word: Monologue: at position 310
# reading until character/word: [END]
# Mono at position 18468
# total copied characters: 18158
#
# retrieving from: https://www.seinfeldscripts.com/ThePledgeDrive.html
# episode title: The Pledge Drive
# reading from character/word: Opening mo at position 958
# reading until character/word: Episodes O at position 45086
# total copied characters: 44128
#
# retrieving from: https://www.seinfeldscripts.com/TheChineseWoman.htm
# episode title: The Chinese Woman
# reading from character/word: Opening Mo at position 890
# reading until character/word: <Spellchec at position 24397
# total copied characters: 23507
#
# retrieving from: https://www.seinfeldscripts.com/TheCouch.html
# episode title: The Couch
# reading from character/word: Jerry's st at position 627
# reading until character/word: Episodes O at position 47021
# total copied characters: 46394
#
# retrieving from: https://www.seinfeldscripts.com/TheGymnast.html
# episode title: The Gymnast
# reading from character/word: [Nightclub at position 387
# reading until character/word: Episodes O at position 21971
# total copied characters: 21584
#
# retrieving from: https://www.seinfeldscripts.com/TheSoup.html
# episode title: The Soup
# reading from character/word: Opening mo at position 899
# reading until character/word: Episodes O at position 31670
# total copied characters: 30771
#
# retrieving from: https://www.seinfeldscripts.com/TheMomAndPopStore.html
# episode title: The Mom and Pop Store
# reading from character/word: Jerry's st at position 693
# reading until character/word: Episodes O at position 49028
# total copied characters: 48335
#
# retrieving from: https://www.seinfeldscripts.com/TheSecretary.html
# episode title: The Secretary
# reading from character/word: Opening mo at position 966
# reading until character/word: Episodes O at position 69860
# total copied characters: 68894
#
# retrieving from: https://www.seinfeldscripts.com/TheRace.html
# episode title: The Race
# reading from character/word: MonologueT at position 346
# reading until character/word: [END]
#
# Tra at position 20625
# total copied characters: 20279
#
# retrieving from: https://www.seinfeldscripts.com/TheSwitch.htm
# episode title: The Switch
# reading from character/word: Opening Mo at position 443
# reading until character/word: Episodes O at position 19326
# total copied characters: 18883
#
# retrieving from: https://www.seinfeldscripts.com/TheLabelMaker.html
# episode title: The Label Maker
# reading from character/word: Opening mo at position 1140
# reading until character/word: Episodes O at position 48203
# total copied characters: 47063
#
# retrieving from: https://www.seinfeldscripts.com/TheScofflaw.htm
# episode title: The Scofflaw
# reading from character/word: [Nightclub at position 453
# reading until character/word: [END]
#
# Tra at position 28288
# total copied characters: 27835
#
# retrieving from: https://www.seinfeldscripts.com/TheBeard.htm
# episode title: The Beard
# reading from character/word: Opening Mo at position 466
# reading until character/word: Episodes O at position 19802
# total copied characters: 19336
#
# retrieving from: https://www.seinfeldscripts.com/TheKissHello.html
# episode title: The Kiss Hello
# reading from character/word: [Nightclub at position 590
# reading until character/word: [END]
# Epis at position 34130
# total copied characters: 33540
#
# retrieving from: https://www.seinfeldscripts.com/TheDoorman.html
# episode title: The Doorman
# reading from character/word: [Nightclub at position 568
# reading until character/word: [END]
#
# Epi at position 33252
# total copied characters: 32684
#
# retrieving from: https://www.seinfeldscripts.com/TheJimmy.htm
# episode title: The Jimmy
# reading from character/word: Opening Mo at position 323
# reading until character/word: Episodes O at position 22074
# total copied characters: 21751
#
# retrieving from: https://www.seinfeldscripts.com/TheDoodle.htm
# episode title: The Doodle
# reading from character/word: Opening Mo at position 484
# reading until character/word: Episodes O at position 20790
# total copied characters: 20306
#
# retrieving from: https://www.seinfeldscripts.com/TheFusilliJerry.htm
# episode title: The Fusille Jerry
# reading from character/word: Opening Mo at position 766
# reading until character/word: [END]
#
# Scr at position 23658
# total copied characters: 22892
#
# retrieving from: https://www.seinfeldscripts.com/TheDiplomatClub.htm
# episode title: The Diplomat Club
# reading from character/word: Opening mo at position 297
# reading until character/word: <Spellchec at position 20649
# total copied characters: 20352
#
# retrieving from: https://www.seinfeldscripts.com/TheFacePainter.html
# episode title: The Face Painter
# reading from character/word: Opening mo at position 838
# reading until character/word: Episodes O at position 23046
# total copied characters: 22208
#
# retrieving from: https://www.seinfeldscripts.com/TheUnderstudy.html
# episode title: The Understudy
# reading from character/word: Jerry and  at position 908
# reading until character/word: [END]
# Epis at position 17161
# total copied characters: 16253
#
# retrieving from: https://www.seinfeldscripts.com/TheEngagement.html
# episode title: The Engagement
# reading from character/word: [George's  at position 378
# reading until character/word: Episodes O at position 17037
# total copied characters: 16659
#
# retrieving from: https://www.seinfeldscripts.com/ThePostponement.html
# episode title: The Postponement
# reading from character/word: [Jerry: an at position 215
# reading until character/word: [END]
# Epis at position 19613
# total copied characters: 19398
#
# retrieving from: https://www.seinfeldscripts.com/TheMaestro.htm
# episode title: The Maestro
# reading from character/word: [Setting:  at position 498
# reading until character/word: [END]
# Epis at position 24622
# total copied characters: 24124
#
# retrieving from: https://www.seinfeldscripts.com/TheWink.html
# episode title: The Wink
# reading from character/word: [Elaine's  at position 279
# reading until character/word: Episodes O at position 21130
# total copied characters: 20851
#
# retrieving from: https://www.seinfeldscripts.com/TheHotTub.htm
# episode title: The Hot Tub
# reading from character/word: Jerry's st at position 786
# reading until character/word: Episodes O at position 25389
# total copied characters: 24603
#
# retrieving from: https://www.seinfeldscripts.com/TheSoupNazi.htm
# episode title: The Soup Nazi
# reading from character/word: GEORGE: Al at position 499
# reading until character/word: <Spell che at position 20706
# total copied characters: 20207
#
# retrieving from: https://www.seinfeldscripts.com/TheSecretCode2.htm
# episode title: The Secret Code
# reading from character/word: Opening mo at position 600
# reading until character/word: Episodes O at position 23240
# total copied characters: 22640
#
# retrieving from: https://www.seinfeldscripts.com/ThePoolGuy.html
# episode title: The Pool Guy
# reading from character/word: Opening mo at position 825
# reading until character/word: Episodes O at position 31788
# total copied characters: 30963
#
# retrieving from: https://www.seinfeldscripts.com/TheSponge.html
# episode title: The Sponge
# reading from character/word: Jerry's st at position 485
# reading until character/word: Episodes O at position 22703
# total copied characters: 22218
#
# retrieving from: https://www.seinfeldscripts.com/TheGum.html
# episode title: The Gum
# reading from character/word: [Nightclub at position 381
# reading until character/word: [END]
# Epis at position 31966
# total copied characters: 31585
#
# retrieving from: https://www.seinfeldscripts.com/TheRye.htm
# episode title: The Rye
# reading from character/word: ELAINE: [t at position 506
# reading until character/word: <Spell che at position 19099
# total copied characters: 18593
#
# retrieving from: https://www.seinfeldscripts.com/TheCaddy.html
# episode title: The Caddy
# reading from character/word: (Scene: Je at position 1182
# reading until character/word: Episodes O at position 24533
# total copied characters: 23351
#
# retrieving from: https://www.seinfeldscripts.com/TheSeven.html
# episode title: The Seven
# reading from character/word: [Nightclub at position 403
# reading until character/word: [End]
# 7.13 at position 32998
# total copied characters: 32595
#
# retrieving from: https://www.seinfeldscripts.com/TheCadillac1.html
# episode title: The Cadillac (1)
# reading from character/word: [Jerry's A at position 434
# reading until character/word: [END]
#
# Epi at position 29125
# total copied characters: 28691
#
# retrieving from: https://www.seinfeldscripts.com/TheCadillac2.html
# episode title: The Cadillac (2)
# reading from character/word: [Montage]  at position 520
# reading until character/word: [END]
#
# Epi at position 25961
# total copied characters: 25441
#
# retrieving from: https://www.seinfeldscripts.com/TheShowerhead.htm
# episode title: The Shower Head
# reading from character/word: monologue. at position 884
# reading until character/word: Episodes O at position 23654
# total copied characters: 22770
#
# retrieving from: https://www.seinfeldscripts.com/TheDoll.htm
# episode title: The Doll
# reading from character/word: Opening mo at position 321
# reading until character/word: END OF SHO at position 28344
# total copied characters: 28023
#
# retrieving from: https://www.seinfeldscripts.com/TheFriarsClub.html
# episode title: The Friars Club
# reading from character/word: [Nightclub at position 679
# reading until character/word: [End] Orig at position 36918
# total copied characters: 36239
#
# retrieving from: https://www.seinfeldscripts.com/TheWigMaster.htm
# episode title: The Wig Master
# reading from character/word: Opening mo at position 385
# reading until character/word: Episodes O at position 23415
# total copied characters: 23030
#
# retrieving from: https://www.seinfeldscripts.com/TheCalzone.htm
# episode title: The Calzone
# reading from character/word: George in  at position 229
# reading until character/word: Episodes O at position 19385
# total copied characters: 19156
#
# retrieving from: https://www.seinfeldscripts.com/TheBottleDeposit1.html
# episode title: The Bottle Deposit (1)
# reading from character/word: [Nightclub at position 329
# reading until character/word: Episodes O at position 26106
# total copied characters: 25777
#
# retrieving from: https://www.seinfeldscripts.com/TheBottleDeposit2.html
# episode title: The Bottle Deposit (2)
# reading from character/word: [Montage o at position 402
# reading until character/word: [END]
#
# Tra at position 27665
# total copied characters: 27263
#
# retrieving from: https://www.seinfeldscripts.com/TheWaitOut.htm
# episode title: The Wait Out
# reading from character/word: [Setting:  at position 276
# reading until character/word: Episodes O at position 8795
# total copied characters: 8519
#
# retrieving from: https://www.seinfeldscripts.com/TheInvitations.htm
# episode title: The Invitations
# reading from character/word: Opening mo at position 416
# reading until character/word: Episodes O at position 20273
# total copied characters: 19857
#
# retrieving from: https://www.seinfeldscripts.com/TheFoundation.html
# episode title: The Foundation
# reading from character/word: First scen at position 672
# reading until character/word: Episodes O at position 21844
# total copied characters: 21172
#
# retrieving from: https://www.seinfeldscripts.com/TheSoulMate.html
# episode title: The Soul Mate
# reading from character/word: Opening sc at position 535
# reading until character/word: Episodes O at position 43598
# total copied characters: 43063
#
# retrieving from: https://www.seinfeldscripts.com/TheBizarroJerry.htm
# episode title: The Bizarro Jerry
# reading from character/word: [JERRY and at position 1
# reading until character/word: <Spellchec at position 24814
# total copied characters: 24813
#
# retrieving from: https://www.seinfeldscripts.com/TheLittleKicks.htm
# episode title: The Little Kicks
# reading from character/word: Jerry and  at position 286
# reading until character/word: <Spellchec at position 19606
# total copied characters: 19320
#
# retrieving from: https://www.seinfeldscripts.com/ThePackage.htm
# episode title: The Package
# reading from character/word: Elaine at  at position 263
# reading until character/word: <Spell che at position 18033
# total copied characters: 17770
#
# retrieving from: https://www.seinfeldscripts.com/TheFatigues.html
# episode title: The Fatigues
# reading from character/word: First scen at position 662
# reading until character/word: Episodes O at position 20095
# total copied characters: 19433
#
# retrieving from: https://www.seinfeldscripts.com/TheChecks.html
# episode title: The Checks
# reading from character/word: Jerry and  at position 522
# reading until character/word: [End] Orig at position 35442
# total copied characters: 34920
#
# retrieving from: https://www.seinfeldscripts.com/TheChickenRoaster.htm
# episode title: The Chicken Roaster
# reading from character/word: George: Wh at position 98
# reading until character/word: <Spellchec at position 19957
# total copied characters: 19859
#
# retrieving from: https://www.seinfeldscripts.com/TheAbstinence.htm
# episode title: The Abstinence
# reading from character/word: Jerry and  at position 39
# reading until character/word: Episodes O at position 39637
# total copied characters: 39598
#
# retrieving from: https://www.seinfeldscripts.com/TheAndreaDoria.htm
# episode title: The Andrea Doria
# reading from character/word: [Setting:  at position 230
# reading until character/word: END OF SHO at position 27193
# total copied characters: 26963
#
# retrieving from: https://www.seinfeldscripts.com/TheLittleJerry.html
# episode title: The Little Jerry
# reading from character/word: Opening sc at position 393
# reading until character/word: Episodes O at position 23132
# total copied characters: 22739
#
# retrieving from: https://www.seinfeldscripts.com/TheMoney.html
# episode title: The Money
# reading from character/word: [Jerry's A at position 1798
# reading until character/word: [END]Origi at position 30935
# total copied characters: 29137
#
# retrieving from: https://www.seinfeldscripts.com/TheComeback.html
# episode title: The Comeback
# reading from character/word: GEORGE: (t at position 1169
# reading until character/word: [END] Tran at position 33278
# total copied characters: 32109
#
# retrieving from: https://www.seinfeldscripts.com/TheVanBurenBoys.htm
# episode title: The Van Buren Boys
# reading from character/word: [Setting:  at position 264
# reading until character/word: END OF SHO at position 23823
# total copied characters: 23559
#
# retrieving from: https://www.seinfeldscripts.com/TheSuzie.htm
# episode title: The Susie
# reading from character/word: high LS fo at position 2502
# reading until character/word: <Spell che at position 35798
# total copied characters: 33296
#
# retrieving from: https://www.seinfeldscripts.com/ThePothole.htm
# episode title: The Pothole
# reading from character/word: Jerry and  at position 1590
# reading until character/word: [End]
#
# Epi at position 32447
# total copied characters: 30857
#
# retrieving from: https://www.seinfeldscripts.com/TheEnglishPatient.html
# episode title: The English Patient
# reading from character/word: Jerry and  at position 771
# reading until character/word: [End]
# Orig at position 33918
# total copied characters: 33147
#
# retrieving from: https://www.seinfeldscripts.com/TheNap.html
# episode title: The Nap
# reading from character/word: [Monks]
# GE at position 375
# reading until character/word: Episodes O at position 17726
# total copied characters: 17351
#
# retrieving from: https://www.seinfeldscripts.com/TheYadaYada.htm
# episode title: The Yada Yada
# reading from character/word: George: So at position 92
# reading until character/word: <Spell che at position 18220
# total copied characters: 18128
#
# retrieving from: https://www.seinfeldscripts.com/TheMillennium.html
# episode title: The Millennium
# reading from character/word: [Jerry's A at position 1800
# reading until character/word: [END]
# Epis at position 28710
# total copied characters: 26910
#
# retrieving from: https://www.seinfeldscripts.com/TheMuffinTops.htm
# episode title: The Muffin Tops
# reading from character/word: Jerry and  at position 590
# reading until character/word: Episodes O at position 21476
# total copied characters: 20886
#
# retrieving from: https://www.seinfeldscripts.com/TheSummerofGeorge.htm
# episode title: The Summer of George
# reading from character/word: [George an at position 1367
# reading until character/word: Episodes O at position 21950
# total copied characters: 20583
#
# retrieving from: https://www.seinfeldscripts.com/TheButterShave.htm
# episode title: The Butter Shave
# reading from character/word: monologue
#  at position 1116
# reading until character/word: Episodes O at position 22871
# total copied characters: 21755
#
# retrieving from: https://www.seinfeldscripts.com/TheVoice.htm
# episode title: The Voice
# reading from character/word: (Scene: In at position 32
# reading until character/word: Episodes O at position 22222
# total copied characters: 22190
#
# retrieving from: https://www.seinfeldscripts.com/TheSerenityNow.htm
# episode title: The Serenity Now
# reading from character/word: The Costan at position 411
# reading until character/word: <Spell che at position 19504
# total copied characters: 19093
#
# retrieving from: https://www.seinfeldscripts.com/TheBlood.html
# episode title: The Blood
# reading from character/word: [Jerry's A at position 510
# reading until character/word: Episodes O at position 21264
# total copied characters: 20754
#
# retrieving from: https://www.seinfeldscripts.com/TheJunkMail.htm
# episode title: The Junk Mail
# reading from character/word: Jerry, on  at position 36
# reading until character/word: Episodes O at position 20480
# total copied characters: 20444
#
# retrieving from: https://www.seinfeldscripts.com/TheMervGriffinShow.htm
# episode title: The Merv Griffin Show
# reading from character/word: Jerry and  at position 329
# reading until character/word: Episodes O at position 17716
# total copied characters: 17387
#
# retrieving from: https://www.seinfeldscripts.com/TheSlicer.html
# episode title: The Slicer
# reading from character/word: [Elaine wa at position 486
# reading until character/word: Episodes O at position 23067
# total copied characters: 22581
#
# retrieving from: https://www.seinfeldscripts.com/TheBetrayal.htm
# episode title: The Betrayal
# reading from character/word: (The final at position 383
# reading until character/word: END OF SHO at position 28901
# total copied characters: 28518
#
# retrieving from: https://www.seinfeldscripts.com/TheApology.htm
# episode title: The Apology
# reading from character/word: Jerry, [ta at position 33
# reading until character/word: Episodes O at position 45504
# total copied characters: 45471
#
# retrieving from: https://www.seinfeldscripts.com/TheStrike.htm
# episode title: The Strike
# reading from character/word: [Setting:  at position 394
# reading until character/word: END OF SHO at position 25214
# total copied characters: 24820
#
# retrieving from: https://www.seinfeldscripts.com/TheDealership.htm
# episode title: The Dealership
# reading from character/word: [Setting:  at position 274
# reading until character/word: END OF SHO at position 28007
# total copied characters: 27733
#
# retrieving from: https://www.seinfeldscripts.com/TheReversePeephole.htm
# episode title: The Reverse Peephole
# reading from character/word: Waitress g at position 19
# reading until character/word: Episodes O at position 21979
# total copied characters: 21960
#
# retrieving from: https://www.seinfeldscripts.com/TheCartoon.htm
# episode title: The Cartoon
# reading from character/word: Some stree at position 345
# reading until character/word: Episodes O at position 21225
# total copied characters: 20880
#
# retrieving from: https://www.seinfeldscripts.com/TheStrongbox.htm
# episode title: The Strongbox
# reading from character/word: George, dr at position 1
# reading until character/word: Episodes O at position 22199
# total copied characters: 22198
#
# retrieving from: https://www.seinfeldscripts.com/TheWizard.htm
# episode title: The Wizard
# reading from character/word: George: "K at position 21
# reading until character/word: Episodes O at position 20998
# total copied characters: 20977
#
# retrieving from: https://www.seinfeldscripts.com/TheBurning.html
# episode title: The Burning
# reading from character/word: First scen at position 849
# reading until character/word: Episodes O at position 41684
# total copied characters: 40835
#
# retrieving from: https://www.seinfeldscripts.com/TheBookstore.htm
# episode title: The Bookstore
# reading from character/word: [Setting:  at position 361
# reading until character/word: Episodes O at position 24146
# total copied characters: 23785
#
# retrieving from: https://www.seinfeldscripts.com/TheFrogger.htm
# episode title: The Frogger
# reading from character/word: INT. J. PE at position 1
# reading until character/word: <Spellchec at position 23650
# total copied characters: 23649
#
# retrieving from: https://www.seinfeldscripts.com/TheMaid.htm
# episode title: The Maid
# reading from character/word: INT. MONK' at position 1
# reading until character/word: <Spellchec at position 22378
# total copied characters: 22377
#
# retrieving from: https://www.seinfeldscripts.com/ThePuertoRicanDay.htm
# episode title: The Puerto Rican Day
# reading from character/word: INT. JERRY at position 1
# reading until character/word: <Spell che at position 22943
# total copied characters: 22942
#
# retrieving from: https://www.seinfeldscripts.com/TheFinale.htm
# episode title: The Finale (1)
# reading from character/word: Monologue, at position 2
# reading until character/word: <Spellchec at position 46512
# total copied characters: 46510

# %%
with open("Seinfeld_full_scripts.txt", "w", encoding="utf-8") as file: # w is for write mode, encoding is for cross-platform compatibility
    i = 0
    for script in all_scripts:
        file.write(all_titles[i] + "\n\n")
        file.write(script + "\n\n") # add two lines between episode scripts
        i += 1

# %%
with open("seinfeld_full_scripts.txt", "r") as file:
    script = file.readlines()

# Loop through each line and uppercase character names
threshold = 1024
standardized_script = []
for line in script:
    if ':' in line:
        # Split by the first colon to separate the character name from dialogue
        character, dialogue = line.split(':', 1)
        # Capitalize the character name and reassemble the line
        line = f"{character.upper()}:{dialogue}"
    while len(line) > threshold:
        standardized_script.append(line[:threshold] + '\n')
        line = line[threshold:]
    standardized_script.append(line)

# Join all lines back into a single script
standardized_script = ''.join(standardized_script)

# Save or print the result
with open("standardized_seinfeld_script.txt", "w") as file:
    file.write(standardized_script)
